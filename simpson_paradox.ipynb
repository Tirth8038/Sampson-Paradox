# %% [markdown]
# # Simpson Paradox
# It states that, “The trend or result that appears in several different groups of data but it reverses or disappears when the data is combined.”

# %%
#Importing Necessary Libraries 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

data_path="/Users/macbook/Downloads/data_to_show.csv"
data=pd.read_csv(data_path)

# %%
#Data to Show
data
# Out:
#       Unnamed: 0          x1           y
# 0              0  118.806042  235.460634
# 1              1   77.906308  195.656912
# 2              2  109.102973  193.948473
# 3              3  122.763420  230.122876
# 4              4   70.846286  152.185975
# ...          ...         ...         ...
# 2995        2995  213.947800   98.670263
# 2996        2996  202.772492  135.100387
# 2997        2997  199.465292  126.359718
# 2998        2998  210.940939   69.183450
# 2999        2999  178.239602   78.400796
#
# [3000 rows x 3 columns]

# %%
#Splitting the data into Features and Labels
X=data['x1']
y=data['y']

# %%
#Converting the dataset into array and reshaping it
import numpy as np
X=np.array(X).reshape(-1,1)
y=np.array(y).reshape(-1,1)

# %%
#Using Linear Regression to Train the Model
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#Visualization
sns.regplot(data=data, x=X, y=y, color='olive', marker="+")
plt.title("Simpson Paradox")
plt.xlabel('x1')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# # Simpson Paradox using Synthetic Dataset
# To demonstrate the Simpson Paradox, I generated 2 random normally distributed numpy arrays of range (2,2000) and Generated New Array "C_new" by performing arithmatic Operation using A and B.

# %%
#Creating new Custom data to show Simpson's Paradox 
B_syn = []
C_new = []
for i in range(3):
    #Creating 2 random normally distributed numpy arrays of range (2,2000)
    A = np.random.normal(2, 5, 2000)
    B = np.random.normal(2, 5, 2000)
    for j in range(len(A)):
        #Performing Arithmatic Operation using A and B to Generate Combined New Array "C_new"
        B_syn.append((2*B[j]) + (20*i))
        C_new.append((0.5*B[j]) + A[j] - (40*i))

# %%
#Shape of the generated Dataset
A.shape , B.shape
# Out:
# ((2000,), (2000,))

# %%
#Plotting the data
plt.plot(B_syn, C_new,'r+')
plt.xlabel('A')
plt.ylabel('B')
plt.show()

# %%
#Converting the synthetic dataset into array and reshaping it
B = np.array(B_syn).reshape(-1, 1)
C = np.array(C_new).reshape(-1, 1)

# %%
#Using Linear Regression to Train the Model
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(B,C)
# Out:
# LinearRegression()

# %%
#Making Prediction using Training Data B
y= model.predict(B)
y
# Out:
# array([[-15.7266481 ],
#        [ -7.29212129],
#        [-29.1275251 ],
#        ...,
#        [-73.94847268],
#        [-66.28041322],
#        [-76.53246545]])

# %%
#Visualizing the Simpson Paradox Using Combined Synthetic Data 
plt.plot(B, C,'r+')
plt.plot(B, y, '-')
plt.xlabel('New B')
plt.ylabel('Combined')
plt.title("Simpson Paradox for Synthetic Data")
# Out:
# Text(0.5, 1.0, 'Simpson Paradox for Synthetic Data')
